# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd drive/MyDrive/updated_maddpg

# %%
import torch

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(DEVICE)
# print(torch.cuda.is_available())
# Out:
# cuda:0

# %%
# %pip install pettingzoo[mpe]

# %%
# !python3 "main.py"
# Out:
# episode 100, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: 0.000000; sum reward: 0.0
# episode 200, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: 0.000000; sum reward: 0.0
# episode 300, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: -16.886618; sum reward: -16.88661810302194
# episode 400, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: 0.000000; sum reward: 0.0
# episode 500, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: -0.049917; sum reward: -0.049916670202158064
# episode 600, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: 0.000000; sum reward: 0.0
# episode 700, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: -4.723520; sum reward: -4.7235197829372755
# episode 800, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: 0.000000; sum reward: 0.0
# episode 900, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: 0.000000; sum reward: 0.0
# episode 1000, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: 0.000000; sum reward: 0.0
# episode 1100, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: 0.000000; sum reward: 0.0
# episode 1200, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: 0.000000; sum reward: 0.0
# episode 1300, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: 0.000000; sum reward: 0.0
# episode 1400, adversary_0: 20.000000; adversary_1: 20.000000; adversary_2: 20.000000; agent_0: -20.000000; sum reward: 40.0
# episode 1500, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: 0.000000; sum reward: 0.0
# episode 1600, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: -0.417624; sum reward: -0.4176238698683554
# episode 1700, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: 0.000000; sum reward: 0.0
# episode 1800, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: -4.833323; sum reward: -4.833323287164408
# episode 1900, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: 0.000000; sum reward: 0.0
# episode 2000, adversary_0: 20.000000; adversary_1: 20.000000; adversary_2: 20.000000; agent_0: -20.000000; sum reward: 40.0
# episode 2100, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: -1.148331; sum reward: -1.1483311100650828
# episode 2200, adversary_0: 10.000000; adversary_1: 10.000000; adversary_2: 10.000000; agent_0: -35.454048; sum reward: -5.454048087421114
# episode 2300, adversary_0: 0.000000; adversary_1: 0.000000; adversary_2: 0.000000; agent_0: -32.169478; sum reward: -32.169478094949916
